# %% [markdown]
# # Fit the CB models based on optimized parameters

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import os
import re, string, unicodedata
import nltk
import contractions
import inflect

import lime
from lime import lime_text
from lime.lime_text import LimeTextExplainer

import re

from wordcloud import WordCloud, STOPWORDS

import nltk
# import contractions
import inflect
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk import SnowballStemmer
from nltk.stem import LancasterStemmer, WordNetLemmatizer


from sklearn import metrics
from sklearn.model_selection import train_test_split
# from keras.preprocessing.sequence import pad_sequences

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
from sklearn.preprocessing import OneHotEncoder

import scipy

from gensim import corpora
from gensim import corpora
from gensim.similarities.docsim import Similarity
from gensim import corpora, models, similarities

import pickle
import time
import Utils as util

# %% [markdown]
# ## Load all functions

# %%
### Text Prepocessing
def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
            
    return new_words

def remove_special(words):
    """Remove special signs like &*"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[-,$()#+&*]', '', word)
        if new_word != '':
            new_words.append(new_word)
            
    return new_words

def replace_numbers(words):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
            
    return new_words

def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""  
    stopwords = nltk.corpus.stopwords.words('english')
    myStopWords = []
    stopwords.extend(myStopWords)
    new_words = []
    for word in words:
        if word not in stopwords:
            new_words.append(word)
            
    return new_words

def to_lowercase(words):
    """Convert words to lowercase"""
    new_words=[]
    for word in words:
        new_words.append(word.lower())
        
    return new_words

def stem_words(words):
    """Stem words in list of tokenized words"""
    stemmer = LancasterStemmer()
    stemmer = SnowballStemmer('english')
    stems = []
    for word in words:
        stem = stemmer.stem(word)
        stems.append(stem)
        
    return stems

def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
        
    return lemmas

def normalize_lemmatize(words):
    words = remove_special(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = replace_numbers(words)
    words = remove_stopwords(words)
    words = stem_words(words)
    words = lemmatize_verbs(words)
    return words

def get_processed(sample):
    processed = pd.DataFrame(data=[],columns = ['business_id', 'text'])
    new_texts = []

    for i in range(0, len(sample)):
        business_id = sample['business_id'].iloc[i]
        words = nltk.word_tokenize(sample['text'].iloc[i])
        text = ' '.join(normalize_lemmatize(words))
        dfnew = pd.DataFrame([[business_id, text]], columns=['business_id', 'text'])
        new_texts.append(text)
        processed = processed.append(dfnew,ignore_index = True)
    return processed

## Similarity matrix

def get_tfidf_matrix(processed):
    '''
    get the Tf-Idf matrix of processed texts for business reviews
    
    '''
    TV = TfidfVectorizer(stop_words = "english")
    processed["text"] = processed["text"].fillna('')
    tfidf_matrix = TV.fit_transform((processed["text"]))
    
    return tfidf_matrix

def get_cos_sim_matrix(tfidf_matrix, n):
    '''
    use truncated SVD to reduce dimensions to n 
    @n: the dimensions to keep
    '''
    SVD = TruncatedSVD(n_components = n , random_state = 42) # 42 is the ultimate answer to everything
    tfidf_truncated = SVD.fit_transform(tfidf_matrix)
    cosine_sim = cosine_similarity(tfidf_truncated, tfidf_truncated)
    
    return cosine_sim

def get_euclidean_sim(business, n_components):
    
    SVD = TruncatedSVD(n_components = n_components , random_state = 42) # 42 is the ultimate answer to everything
    bus_truncated = SVD.fit_transform(business)
    
    eucl_dist = euclidean_distances(bus_truncated)
    eucl_sim = 1/np.exp(eucl_dist)
    return eucl_sim
    
def get_buscosine_sim(business,n_components):
    SVD = TruncatedSVD(n_components = n_components , random_state = 42) # 42 is the ultimate answer to everything
    bus_truncated = SVD.fit_transform(business)
    
    cosine_sim = cosine_similarity(bus_truncated, bus_truncated)
    return cosine_sim

def get_mix_sim_matrix(cosine_sim, bus_cos_sim, lmbda = 0.5, ):
    mixed_sim = np.add(cosine_sim*lmbda, bus_cos_sim*(1-lmbda)) # assume equally weighted

    return mixed_sim

def get_mix_sim_df(df_tfidf_sim, df_bus_sim, lmbda = 0.5):
    df_tfidf_pivot = pd.melt(df_tfidf_sim.reset_index(), id_vars = "index" , value_vars = df_tfidf_sim.columns.values)
    df_bus_pivot = pd.melt(df_bus_sim.reset_index(), id_vars = "index" , value_vars = df_bus_sim.columns.values)
    
    df_merge = pd.merge(df_tfidf_pivot, df_bus_pivot, on = ["index", "variable"])
    df_merge["value"] = (lmbda) * df_merge["value_x"] + (1-lmbda) * df_merge["value_y"]
    
    df_mixed_sim = pd.pivot(df_merge, index="index", columns="variable", values ="value")
    return df_mixed_sim
## Get recommendations and prediction
def get_recommendation_cos(reviews, business_id, user_id, df_sim, k):
    '''get the business_id_array that shows top_k greatest similarity to the specific business_id'''
    user_bids = reviews[reviews['user_id']==user_id]['business_id'].values
    df_user = df_sim.loc[df_sim.index.isin(user_bids), df_sim.columns == business_id]
    df_user_topk = df_user.sort_values(df_user.columns[0], ascending = False).iloc[:k]
    
    return np.array(df_user_topk.index.values)


def predict_rating(reviews, user_id, business_ids):
    '''predict the avg of the user's rating on business in business_ids'''
    scores = reviews.loc[(reviews.user_id == user_id) & (reviews.business_id.isin(business_ids))]["stars"].values
    
    return np.mean(scores)


def get_results_cos(reviews, reviews_test, business_id, user_id, df_sim, k):
    '''
    prediction on the business_id：avg the ratings on top_k business that shows similarity to the business_id
    actual on the business_id: the true rating 
    '''
    actual = reviews_test.loc[(reviews_test.user_id==user_id) & (reviews_test.business_id==business_id)]['stars'].values[0]
    business_ids = get_recommendation_cos(reviews, business_id, user_id, df_sim, k)
    prediction = predict_rating(reviews, user_id, business_ids)
    
    return actual, prediction

def get_review_processed(processed, reviews):
    reviews_processed = reviews.loc[reviews.business_id.isin(processed.business_id)]\
                                                       .reset_index()\
                                                       .drop(columns=['index'])
    return reviews_processed

def CB_predict(reviews, reviews_test, df_sim, k = 5):
    '''
    based on test_df 
    get a dataframe with each user on each business's true ratings and prediction ratings
    @df_sim, n*n DataFrame for business similarities
    @k: int, top k similar businesses
    '''
    user_id_sample = reviews_test['user_id'].values
    busi_id_sample = reviews_test['business_id'].values
    
    actual = []
    predictions = []
    
    for i in range(len(reviews_test)):
        try:
            act, pred = get_results_cos(reviews, reviews_test, busi_id_sample[i], user_id_sample[i], df_sim, k)
            actual.append(act)
            predictions.append(pred)
            
        except:
            actual.append(np.nan)
            predictions.append(np.nan)
            
    return pd.DataFrame({"user_id": user_id_sample,
                         "business_id": busi_id_sample,
                         "true_ratings": actual,
                         "prediction_ratings":  predictions                        
                        })

## LSI model
def get_lsi(processed, reviews, user_id, n_topics):
    '''
    get the lsi model for user_id
    '''
    user_bids = reviews[reviews['user_id']==user_id]['business_id'].values
    processed_user = processed.loc[processed.business_id.isin(user_bids)]
    documents = list(processed_user['text'].values)
    texts = [[word for word in document.split(' ')] for document in documents]
    dictionary = corpora.Dictionary(texts)
    corpus = [dictionary.doc2bow(text) for text in texts] 

    lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=n_topics)
    
    return lsi, dictionary, corpus

def get_recommendation_lsi(processed, reviews, df_lsi, business_id, user_id, k, n_topics):
    lsi = df_lsi[(df_lsi["n_topic"] == n_topics) & (df_lsi["user_id"] == user_id)]["lsi"][0]
    dictionary = df_lsi[(df_lsi["n_topic"] == n_topics) & (df_lsi["user_id"] == user_id)]["dictionary"][0]
    user_bids = reviews[reviews['user_id']==user_id]['business_id'].values
    processed_user = processed.loc[processed.business_id.isin(user_bids)]
    documents = list(processed_user['text'].values)
    texts = [[word for word in document.split(' ')] for document in documents]
    corpus = [dictionary.doc2bow(text) for text in texts] 
    
    doc = processed['text'].loc[processed.business_id==business_id].values[0]
    vec_bow = dictionary.doc2bow(doc.lower().split())
    vec_lsi = lsi[vec_bow]
    index = similarities.MatrixSimilarity(lsi[corpus])
    sims = list(index[vec_lsi])
    results = list(zip(user_bids, sims))
    results_ordered = np.array(sorted(results, key=lambda x: x[1], reverse=True))
    results_topk = results_ordered[:k]
    
    return results_topk[:,0]

def get_results_lsi(processed,reviews,reviews_test, df_lsi ,business_id,user_id,k,n_topics):
    actual = reviews_test.loc[(reviews_test.user_id==user_id) & (reviews_test.business_id==business_id)]['stars'].values[0]
    business_ids = get_recommendation_lsi(processed,reviews,df_lsi ,business_id,user_id,k,n_topics)
    prediction = predict_rating(reviews, user_id, business_ids)
    return actual, prediction

def get_recommendation_lsi(processed,reviews,business_id,user_id,k,n_topics):
    user_bids = reviews[reviews['user_id']==user_id]['business_id'].values
    processed_user = processed.loc[processed.business_id.isin(user_bids)]
    documents = list(processed_user['text'].values)
    texts = [[word for word in document.split(' ')] for document in documents]
    dictionary = corpora.Dictionary(texts)
    corpus = [dictionary.doc2bow(text) for text in texts] 

    lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=n_topics)
    doc = processed['text'].loc[processed.business_id==business_id].values[0]
    vec_bow = dictionary.doc2bow(doc.lower().split())
    vec_lsi = lsi[vec_bow]
    index = similarities.MatrixSimilarity(lsi[corpus])
    sims = list(index[vec_lsi])
    results = list(zip(user_bids, sims))
    results_ordered = np.array(sorted(results, key=lambda x: x[1], reverse=True))
    results_topk = results_ordered[:k]
    
    return results_topk[:,0]

def get_results_lsi(processed,reviews,reviews_test ,business_id,user_id,k,n_topics):
    actual = reviews_test.loc[(reviews_test.user_id==user_id) & (reviews_test.business_id==business_id)]['stars'].values[0]
    business_ids = get_recommendation_lsi(processed,reviews,business_id,user_id,k,n_topics)
    prediction = predict_rating(reviews, user_id, business_ids)
    return actual, prediction

def CB_LSI_predict(df_texts_train, reviews, reviews_test, k = 5, n_topics = 100):
    uid_sample = reviews_test['user_id'].values
    bid_sample = reviews_test['business_id'].values
    actual_lsi = []
    predictions_lsi = []
    for i in range(len(reviews_test)):
        try:
            act, pred = get_results_lsi(df_texts_train, reviews, reviews_test, bid_sample[i],uid_sample[i], k, n_topics)
            predictions_lsi.append(pred)
            actual_lsi.append(act)

        except:
            predictions_lsi.append(np.nan)
            actual_lsi.append(np.nan)
            
    return pd.DataFrame({"user_id": uid_sample,
                         "business_id": bid_sample,
                         "ratings": actual_lsi,
                         "pred_lsi":  predictions_lsi})

def get_recommendation_cos_full(reviews, user_id, df_sim, k, busi_id_lst):
    '''get the business_id_array that shows top_k greatest similarity to the specific business_id'''
    
    df_user_rating = reviews[reviews.user_id == user_id]
#     df_sim = df_sim.loc[busi_id_lst, busi_id_lst]
    user_bids = df_user_rating['business_id'].values
    df_user = df_sim.loc[df_sim.index.isin(user_bids)]
    df_user_rank = df_user.rank(ascending = False, axis = 0)
    df_user_rank[df_user_rank <= k] = 1
    df_user_rank[df_user_rank > k] = 0
    df_user_rank = df_user_rank/ np.min([k, len(user_bids)])
  
    user_rating_matrix = np.array(df_user_rating[["business_id", "stars"]].set_index(["business_id"]).loc[df_user_rank.index.values])
    pred = user_rating_matrix.T @ np.array(df_user_rank)
    return pred

def CB_sim_fit_full_matrix(train_valid_df, df_sim, k, user_id_lst, busi_id_lst):
    rating_pred_matrix = np.zeros((len(user_id_lst), len(busi_id_lst)))
    for i,user_id in enumerate(user_id_lst):
        rating_pred_matrix[i,] = get_recommendation_cos_full(train_valid_df, user_id, df_sim, k, busi_id_lst)
    return(rating_pred_matrix)

def get_mse(pred, actual):
    # Ignore zero terms.
    pred = pred[actual.nonzero()].flatten()
    actual = actual[actual.nonzero()].flatten()
    return mean_squared_error(pred, actual)

# %% [markdown]
# ## Load Data

# %%
# cand_users = pickle.load(open('user_mapping', "rb"))
# # cand_rest = pickle.load(open('business_mapping', "rb"))
# list_user = list(cand_users.values())
# # list_rest = list(cand_rest.values())

# %%
## Read data
rev_busi = pd.read_csv('filtered_reviews.csv', parse_dates=["date"])

user_id_lst = rev_busi['user_id'].unique().tolist() # rows of sparse matrix
# user1 = set(user_id)
# user2 = set(list_user)
# user_id_lst = list(user1.intersection(user2))
busi_id_lst = rev_busi['business_id'].unique().tolist() # columns of sparse matrix

# train_valid_df  = pickle.load(open('../data/train_valid_df.pkl', "rb"))
test_df = pickle.load(open('test_df.pkl', "rb"))
train_df  = pickle.load(open('train_df.pkl', "rb"))
valid_df = pickle.load(open('valid_df.pkl', "rb"))
train_valid_df = pickle.load(open('train_valid_df.pkl', "rb"))

train_sparse_matrix = np.load('train_sparse_matrix.npy')
test_sparse_matrix = np.load('test_sparse_matrix.npy')
valid_sparse_matrix = np.load('valid_sparse_matrix.npy')
train_valid_sparse_matrix = np.load('train_valid_sparse_matrix.npy')

bus_df_subset = pd.read_csv("business_subset_cleaned.csv", index_col= "business_id")
bus_df_subset.head(1)
# Out:
#                         latitude  longitude     stars  review_count  is_open  \
# business_id
# MTSW4McQd7CbVtyjqoe9mw  0.637723   0.925908  0.382081     -0.469568        1
#
#                         RestaurantsGoodForGroups  GoodForKids  \
# business_id
# MTSW4McQd7CbVtyjqoe9mw                         0            0
#
#                         RestaurantsReservations  RestaurantsTableService  \
# business_id
# MTSW4McQd7CbVtyjqoe9mw                        0                        0
#
#                         HappyHour  ...  Ambience_upscale  Parking  music  \
# business_id                        ...
# MTSW4McQd7CbVtyjqoe9mw          0  ...                 0        1      0
#
#                         Monday  Tuesday  Wednesday  Thursday  Friday  \
# business_id
# MTSW4McQd7CbVtyjqoe9mw       1        1          1         1       1
#
#                         Saturday  Sunday
# business_id
# MTSW4McQd7CbVtyjqoe9mw         1       1
#
# [1 rows x 37 columns]

# %%
l = pd.DataFrame(user_id_lst)
l.to_csv('user_list.csv')

# %%
l2 = pd.DataFrame(busi_id_lst)
l2.to_csv('rest_list.csv')

# %%
l2.shape
# Out:
# (4312, 1)

# %% [markdown]
# ## 1. non-NLP CB Model (CB_Bus)

# %%
k1 = 15
similarity = "cos" # or "eucl"
n_components1 = 10

if similarity == "cos":
    bus_sim = get_buscosine_sim(bus_df_subset, n_components1)
else:
    bus_sim = get_euclidean_sim(bus_df_subset, n_components1)
    
df_bus_sim  = pd.DataFrame(bus_sim, index= bus_df_subset.index.values, columns=bus_df_subset.index.values)
df_bus_sim.shape
# Out:
# (4312, 4312)

# %%
rev_busi.head(2)
# Out:
#    Unnamed: 0               review_id                 user_id  \
# 0           2  S6pQZQocMB1WHMjTRbt77A  ejFxLGqQcWNLdNByJlIhnQ
# 1           3  WqgTKVqWVHDHjnjEsBvUgg  f7xa0p_1V9lx53iIGN5Sug
#
#               business_id  stars  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw    4.0
# 1  XQfwVwDr-v0ZS3_CbbE5Xw    3.0
#
#                                                 text                date  \
# 0  The place is cute and the staff was very frien... 2017-08-08 00:58:18
# 1  We came on a Saturday morning after waiting a ... 2017-11-19 02:20:23
#
#                            name         city state   category_1  \
# 0  Turning Point of North Wales  North Wales    PA  Restaurants
# 1  Turning Point of North Wales  North Wales    PA  Restaurants
#
#             category_2 category_3
# 0   Breakfast & Brunch       Food
# 1   Breakfast & Brunch       Food

# %%
def get_recommendation_cos_full(reviews, user_id, df_sim, k, busi_id_lst):
    '''get the business_id_array that shows top_k greatest similarity to the specific business_id'''
    
    df_user_rating = reviews[reviews.user_id == user_id]
#     df_sim = df_sim.loc[busi_id_lst, busi_id_lst]
    user_bids = df_user_rating['business_id'].values
    df_user = df_sim.loc[df_sim.index.isin(user_bids)]
    df_user_rank = df_user.rank(ascending = False, axis = 0)
    df_user_rank[df_user_rank <= k] = 1
    df_user_rank[df_user_rank > k] = 0
    df_user_rank = df_user_rank/ np.min([k, len(user_bids)])
  
    user_rating_matrix = np.array(df_user_rating[["business_id", "stars"]].set_index(["business_id"]).loc[df_user_rank.index.values])
    pred = user_rating_matrix.T @ np.array(df_user_rank)
    return pred

def CB_sim_fit_full_matrix(train_valid_df, df_sim, k, user_id_lst, busi_id_lst):
    rating_pred_matrix = np.zeros((len(user_id_lst), len(busi_id_lst)))
    for i,user_id in enumerate(user_id_lst):
        rating_pred_matrix[i,] = get_recommendation_cos_full(train_valid_df, user_id, df_sim, k, busi_id_lst)
    return(rating_pred_matrix)

def get_mse(pred, actual):
    # Ignore zero terms.
    pred = pred[actual.nonzero()].flatten()
    actual = actual[actual.nonzero()].flatten()
    return mean_squared_error(pred, actual)

# %%
#### Generate model fit:
t0 = time.time()
pred_matrix = CB_sim_fit_full_matrix(train_df, df_bus_sim.loc[busi_id_lst, busi_id_lst],k1, user_id_lst, busi_id_lst)
t1 = time.time()
print("time elapsed: (seconds)")
print(np.round(t1 - t0,3))

print("MSE on test set:", get_mse(pred_matrix, valid_sparse_matrix))
# Out:
# time elapsed: (seconds)
# 1040.896
# MSE on test set: 1.429582187631011

# %%
# np.save('pred_matrix.npy',     pred_matrix)
# print("MSE on test set:", get_mse(pred_matrix, valid_sparse_matrix))

# %%
b = get_mse(pred_matrix, valid_sparse_matrix)
b
# Out:
# 1.429582187631011

# %%
pred_matrix
# Out:
# array([[3.8       , 3.93333333, 3.8       , ..., 3.73333333, 3.53333333,
#         3.8       ],
#        [3.66666667, 3.8       , 3.6       , ..., 3.86666667, 3.66666667,
#         3.6       ],
#        [3.85714286, 3.85714286, 3.85714286, ..., 3.85714286, 3.85714286,
#         3.85714286],
#        ...,
#        [2.        , 2.        , 2.        , ..., 2.        , 2.        ,
#         2.        ],
#        [4.        , 4.        , 4.        , ..., 4.        , 4.        ,
#         4.        ],
#        [4.        , 4.        , 4.        , ..., 4.        , 4.        ,
#         4.        ]])

# %%
pred_matrix.shape
# Out:
# (25420, 4312)

# %% [markdown]
# ## 2. CB - similarity with NLP (CB_NLP)

# %%
# df_texts = pickle.load(open('../data/text_train_valid_df.pkl', "rb"))

df_texts = pickle.load(open('text_train_df.pkl', "rb"))


df_texts.head(3)
# Out:
#               business_id                                               text
# 0  -0G_6-KFGpCpxTUlVXCMYQ  taco place good get straightfrommexico varieti...
# 1  -1oygVebK81K8JEPI6H6Lw  awesom find good soup sammi bagel downtown sur...
# 2  -2VYztMXVorktljCdQNPmQ  amaz indian food great flavor alway come chick...

# %%
# Parameters 
n_components2 = 60 #n singular values for reviews' vector space
k2 = 45

# %%
n_components2 = 60 #n singular values for reviews' vector space
k2 = 45
tfidf_matrix = get_tfidf_matrix(df_texts)
cosine_sim = get_cos_sim_matrix(tfidf_matrix, n_components2)
df_tfidf_sim = pd.DataFrame(cosine_sim, index=df_texts['business_id'].values, columns=df_texts['business_id'].values)
df_tfidf_sim.head(1)
# Out:
#                         -0G_6-KFGpCpxTUlVXCMYQ  -1oygVebK81K8JEPI6H6Lw  \
# -0G_6-KFGpCpxTUlVXCMYQ                     1.0                0.146432
#
#                         -2VYztMXVorktljCdQNPmQ  -3Mc8R5c23FxrxlJn3ivww  \
# -0G_6-KFGpCpxTUlVXCMYQ                0.254958                0.303581
#
#                         -3xX_IfttKjPJ792BOBJ-Q  -4x3pVUUsfWmKEilWKsOZQ  \
# -0G_6-KFGpCpxTUlVXCMYQ                0.372595                0.304384
#
#                         -8luB5pJ7d9UOoiF7wikkw  -AWclhh1_2VnqPylPgBU3g  \
# -0G_6-KFGpCpxTUlVXCMYQ                0.257288                0.257924
#
#                         -Dg2pJigtydnPUUW5XBamQ  -DsC3cvCBEy_FNJ7U-i9zg  ...  \
# -0G_6-KFGpCpxTUlVXCMYQ                0.424976                0.360424  ...
#
#                         zl-LqKy7snBF4LKmiVKmNA  zm9aNqkHHtp1f-VT3ZlOZw  \
# -0G_6-KFGpCpxTUlVXCMYQ                0.174277                0.340718
#
#                         zmpRwOqxaajeh2YvAKxLaQ  znlTHyGTSWyqZFYuS0KpmQ  \
# -0G_6-KFGpCpxTUlVXCMYQ                0.361616                0.350934
#
#                         zobY3ws9R2pgbcP0gOImcg  ztnYPn2w0R4lEJL266apzg  \
# -0G_6-KFGpCpxTUlVXCMYQ                 0.32853                0.357429
#
#                         ztppjLmFE25wZOQdJKXAuA  zvGNZF827KyzLupKiG4Xtw  \
# -0G_6-KFGpCpxTUlVXCMYQ                0.250153                 0.38829
#
#                         zwGvMQ7Nw0VwqLUYDuxRXQ  zz0l4dUf28wzPAaTdGqsSw
# -0G_6-KFGpCpxTUlVXCMYQ                0.511297                0.962684
#
# [1 rows x 4312 columns]

# %%
#### Generate model fit:
t0 = time.time()
pred_matrix_nlp = CB_sim_fit_full_matrix(train_df, df_tfidf_sim.loc[busi_id_lst, busi_id_lst],k1, user_id_lst, busi_id_lst)
t1 = time.time()
print("time elapsed: (seconds)")
print(np.round(t1 - t0,3))

# print("MSE on test set:", get_mse(pred_matrix_nlp, valid_sparse_matrix))
# Out:
# time elapsed: (seconds)
# 963.432

# %%
a = get_mse(pred_matrix_nlp, valid_sparse_matrix)
a
# Out:
# 1.435387685657315

# %%
pred_matrix_nlp
# Out:
# array([[3.8       , 3.66666667, 3.86666667, ..., 3.66666667, 3.86666667,
#         3.8       ],
#        [3.8       , 3.66666667, 3.86666667, ..., 3.66666667, 3.66666667,
#         3.8       ],
#        [3.85714286, 3.85714286, 3.85714286, ..., 3.85714286, 3.85714286,
#         3.85714286],
#        ...,
#        [2.        , 2.        , 2.        , ..., 2.        , 2.        ,
#         2.        ],
#        [4.        , 4.        , 4.        , ..., 4.        , 4.        ,
#         4.        ],
#        [4.        , 4.        , 4.        , ..., 4.        , 4.        ,
#         4.        ]])

# %%
np.save('pred_matrix_nlp.npy',     pred_matrix_nlp)
# print("MSE on test set:", get_mse(pred_matrix_nlp, valid_sparse_matrix))

# %%
pred_matrix_nlp.shape
# Out:
# (25420, 4312)

# %%
final_matrix = pred_matrix*(1/b) + pred_matrix_nlp*(1/a)
final_matrix
# Out:
# array([[5.3054877 , 5.30586492, 5.35193276, ..., 5.16596391, 5.16539807,
#         5.3054877 ],
#        [5.21222035, 5.21259758, 5.21203174, ..., 5.25923125, 5.11933023,
#         5.16558668],
#        [5.38526947, 5.38526947, 5.38526947, ..., 5.38526947, 5.38526947,
#         5.38526947],
#        ...,
#        [2.79236195, 2.79236195, 2.79236195, ..., 2.79236195, 2.79236195,
#         2.79236195],
#        [5.58472389, 5.58472389, 5.58472389, ..., 5.58472389, 5.58472389,
#         5.58472389],
#        [5.58472389, 5.58472389, 5.58472389, ..., 5.58472389, 5.58472389,
#         5.58472389]])

# %%
np.save('final_cb_matrix.npy', final_matrix)

# %%
import torch
recom_matrix = torch.tensor(final_matrix)
top_values, top_idx = torch.topk(recom_matrix, 20, 1)

# %%
top_idx
torch.save(top_idx, 'cb_recom.pt')
# Out:
# tensor([[3657, 1002,    5,  ..., 2699, 2712,  257],
#         [ 635, 2465,   26,  ..., 3649,  362,  770],
#         [  18,   10,    4,  ...,    2,    6,   14],
#         ...,
#         [  18,   10,    4,  ...,    2,    6,   14],
#         [  18,   10,    4,  ...,    2,    6,   14],
#         [  18,   10,    4,  ...,    2,    6,   14]])

# %%
for i, li in enumerate(top_idx):
    lis = li.tolist()
    print('User:{}, Top 20 recommendations: {}...'.format(i,lis[:5]))
# Out:
# User:0, Top 20 recommendations: [3657, 1002, 5, 503, 2339]...
# User:1, Top 20 recommendations: [635, 2465, 26, 554, 923]...
# User:2, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:3, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:4, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:5, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:6, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:7, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:8, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:9, Top 20 recommendations: [93, 2382, 2761, 4052, 3491]...
# User:10, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:11, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:12, Top 20 recommendations: [2195, 528, 1641, 520, 958]...
# User:13, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:14, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:15, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:16, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:17, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:18, Top 20 recommendations: [698, 3344, 2245, 396, 1141]...
# User:19, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:20, Top 20 recommendations: [3445, 1481, 4303, 3382, 1718]...
# User:21, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:22, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:23, Top 20 recommendations: [938, 130, 520, 485, 85]...
# User:24, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:26, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:27, Top 20 recommendations: [251, 1238, 397, 1574, 2788]...
# User:28, Top 20 recommendations: [3329, 77, 110, 1428, 3095]...
# User:29, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:30, Top 20 recommendations: [2396, 4293, 439, 2672, 1816]...
# User:31, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:32, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:33, Top 20 recommendations: [513, 1002, 3851, 769, 3978]...
# User:34, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:35, Top 20 recommendations: [3252, 1404, 102, 714, 1741]...
# User:36, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:37, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:38, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:39, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:40, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:41, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:42, Top 20 recommendations: [2304, 1730, 2345, 2676, 212]...
# User:43, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:44, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:45, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:46, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:47, Top 20 recommendations: [671, 1171, 1201, 3646, 4301]...
# User:48, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:49, Top 20 recommendations: [431, 1295, 2151, 526, 3362]...
# User:50, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:51, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:52, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:53, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:54, Top 20 recommendations: [1426, 2621, 117, 2227, 242]...
# User:55, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:56, Top 20 recommendations: [2471, 1161, 3389, 2977, 2733]...
# User:57, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:58, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:59, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:60, Top 20 recommendations: [4042, 4197, 1465, 3528, 1699]...
# User:61, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:62, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:63, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:64, Top 20 recommendations: [2891, 1345, 3514, 130, 2626]...
# User:65, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:66, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:67, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:68, Top 20 recommendations: [545, 1810, 4065, 255, 2360]...
# User:69, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:70, Top 20 recommendations: [635, 2228, 1208, 1876, 55]...
# User:71, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:72, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:73, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:74, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:75, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:76, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:77, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:78, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:79, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:80, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:81, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:82, Top 20 recommendations: [1900, 4296, 635, 129, 3287]...
# User:83, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:84, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:85, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:86, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:87, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:88, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:89, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:90, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:91, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:92, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:93, Top 20 recommendations: [893, 521, 2583, 1312, 3035]...
# User:94, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:95, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:96, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:97, Top 20 recommendations: [2379, 1328, 521, 939, 4080]...
# User:98, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:99, Top 20 recommendations: [1000, 3901, 1788, 46, 3051]...
# User:100, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:101, Top 20 recommendations: [3956, 1876, 4156, 3064, 3047]...
# User:102, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:103, Top 20 recommendations: [434, 1053, 3958, 2264, 2869]...
# User:104, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:105, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:106, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:107, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:108, Top 20 recommendations: [4021, 1768, 3530, 2190, 2621]...
# User:109, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:110, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:111, Top 20 recommendations: [815, 4198, 3047, 1934, 2139]...
# User:112, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User
Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:656, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:657, Top 20 recommendations: [1022, 1727, 815, 280, 4283]...
# User:658, Top 20 recommendations: [109, 57, 89, 157, 41]...
# User:659, Top 20 recommendations: [4176, 722, 516, 25, 387]...
# User:660, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:661, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:662, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:663, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:664, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:665, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:666, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:667, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:668, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:669, Top 20 recommendations: [2671, 3932, 1848, 3886, 3482]...
# User:670, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:671, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:672, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:673, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:674, Top 20 recommendations: [120, 1864, 1925, 3466, 3923]...
# User:675, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:676, Top 20 recommendations: [18, 4, 28, 20, 12]...
# User:677, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:678, Top 20 recommendations: [1833, 1851, 1033, 4044, 1861]...
# User:679, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:680, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:681, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:682, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:683, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:684, Top 20 recommendations: [3415, 1934, 472, 974, 3376]...
# User:685, Top 20 recommendations: [1348, 1462, 4047, 1897, 499]...
# User:686, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:687, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:688, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:689, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:690, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:691, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:692, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:693, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:694, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:695, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:696, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:697, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:698, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:699, Top 20 recommendations: [1861, 3052, 472, 2181, 485]...
# User:700, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:701, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:702, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:703, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:704, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:705, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:706, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:707, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:708, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:709, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:710, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:711, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:712, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:713, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:714, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:715, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:716, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:717, Top 20 recommendations: [264, 2868, 2288, 2264, 2218]...
# User:718, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:719, Top 20 recommendations: [498, 482, 621, 528, 1027]...
# User:720, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:721, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:722, Top 20 recommendations: [1596, 1901, 2433, 482, 957]...
# User:723, Top 20 recommendations: [3086, 2137, 1803, 3867, 3343]...
# User:724, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:725, Top 20 recommendations: [431, 741, 1716, 3455, 1235]...
# User:726, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:727, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:728, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:729, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:730, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:731, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:732, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:733, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:734, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:735, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:736, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:737, Top 20 recommendations: [2626, 964, 1876, 1799, 557]...
# User:738, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:739, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:740, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:741, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:742, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:743, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:744, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:745, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:746, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:747, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:748, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:749, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:750, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:751, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:752, Top 20 recommendations: [1958, 2757, 2856, 2028, 1002]...
# User:753, Top 20 recommendations: [1976, 606, 3773, 3678, 1988]...
# User:754, Top 20 recommendations: [304, 1705, 1713, 2944, 1886]...
# User:755, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:756, Top 20 recommendations: [1908, 389, 737, 3408, 2071]...
# User:757, Top 20 recommendations: [2292, 2074, 3629, 895, 1861]...
# User:758, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:759, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:760, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:761, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:762, Top 20 recommendations: [302, 3877, 2687, 3124, 1596]...
# User:763, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:764, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:765, Top 20 recommendations: [2880, 2269, 2240, 262, 37]...
# User:766, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:767, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:768, Top 20 recommendations: [3594, 2840, 269, 377, 875]...
# User:769, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:770, Top 20 recommendations: [887, 1769, 3941, 485, 2763]...
# User:771, Top 20 recommendations: [2268, 1314, 1133, 892, 1907]...
# User:772, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:773, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:774, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:775, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:776, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:777, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:778, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:779, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:780, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:781, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:782, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:783, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:784, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:785, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:786, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:787, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:788, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:789, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:790, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:791, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:792, Top 20 recommendations: [18, 20, 27, 16, 12]...
# User:793, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:794, Top 20 recommendations: [2155, 1161, 1602, 1634, 224]...
# User:795, Top 20 recommendations: [3376, 3415, 3502, 3514, 4111]...
# User:796, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:797, Top 20 recommendations: [2142, 3189, 2197, 1435, 588]...
# User:798, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:799, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:800, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:801, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:802, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:803, Top 20 recommendations: [110, 3814, 4157, 257, 1864]...
# User:804, Top 20 recommendations: [1513, 3187, 1852, 918, 3589]...
# User:805, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:806, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:807, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:808, Top 20 recommendations: [1513, 2541, 2320, 4294, 2891]...
# User:809, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:810, Top 20 recommendations: [201, 764, 1125, 1160, 4250]...
# User:811, Top 20 recommendations: [18, 10, 4, 16, 12]...
# ...
# User:25149, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25150, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25151, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25152, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25153, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25154, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25155, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25156, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25157, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25158, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25159, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25160, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25161, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25162, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25163, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25164, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25165, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25166, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25167, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25168, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25169, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25170, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25171, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25172, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25173, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25174, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25175, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25176, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25177, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25178, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25179, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25180, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25181, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25182, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25183, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25184, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25185, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25186, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25187, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25188, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25189, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25190, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25191, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25192, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25193, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25194, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25195, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25196, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25197, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25198, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25199, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25200, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25201, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25202, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25203, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25204, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25205, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25206, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25207, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25208, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25209, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25210, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25211, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25212, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25213, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25214, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25215, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25216, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25217, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25218, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25219, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25220, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25221, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25222, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25223, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25224, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25225, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25226, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25227, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25228, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25229, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25230, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25231, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25232, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25233, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25234, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25235, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25236, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25237, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25238, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25239, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25240, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25241, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25242, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25243, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25244, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25245, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25246, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25247, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25248, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25249, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25250, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25251, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25252, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25253, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25254, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25255, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25256, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25257, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25258, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25259, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25260, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25261, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25262, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25263, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25264, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25265, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25266, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25267, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25268, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25269, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25270, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25271, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25272, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25273, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25274, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25275, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25276, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25277, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25278, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25279, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25280, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25281, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25282, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25283, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25284, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25285, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25286, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25287, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25288, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25289, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25290, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25291, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25292, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25293, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25294, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25295, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25296, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25297, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25298, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25299, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25300, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25301, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25302, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25303, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25304, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25305, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25306, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25307, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25308, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25309, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25310, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25311, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25312, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25313, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25314, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25315, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25316, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25317, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25318, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25319, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25320, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25321, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25322, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25323, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25324, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25325, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25326, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25327, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25328, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25329, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25330, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25331, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25332, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25333, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25334, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25335, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25336, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25337, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25338, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25339, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25340, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25341, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25342, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25343, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25344, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25345, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25346, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25347, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25348, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25349, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25350, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25351, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25352, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25353, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25354, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25355, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25356, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25357, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25358, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25359, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25360, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25361, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25362, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25363, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25364, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25365, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25366, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25367, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25368, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25369, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25370, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25371, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25372, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25373, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25374, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25375, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25376, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25377, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25378, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25379, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25380, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25381, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25382, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25383, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25384, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25385, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25386, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25387, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25388, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25389, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25390, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25391, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25392, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25393, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25394, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25395, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25396, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25397, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25398, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25399, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25400, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25401, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25402, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25403, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25404, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25405, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25406, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25407, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25408, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25409, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25410, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25411, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25412, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25413, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25414, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25415, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25416, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25417, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25418, Top 20 recommendations: [18, 10, 4, 16, 12]...
# User:25419, Top 20 recommendations: [18, 10, 4, 16, 12]...

# %%
# top_idx_list = top_idx.tolist()
# top_idx_list.shape

# %% [markdown]
# ## 4. LSI Model

# %%
k4 = 50
n_topics = 50
df_texts = pickle.load(open('text_train_valid_df.pkl', "rb"))

# %%
#### Generate model fit:
t0 = time.time()
df_pred_lsi = util.CB_LSI_predict(df_texts,train_valid_df, test_df, k = k4, n_topics = n_topics)
t1 = time.time()
# print("time elapsed: (seconds)")
# print(np.round(t1 - t0,3))

# %%
# print("MSE on test set:", mean_squared_error(df_pred_lsi.pred_lsi, df_pred_lsi.ratings ))

# %%
# df_pred_lsi
